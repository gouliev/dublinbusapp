# %%
import pandas as pd
import os
import sqlalchemy
import pymysql
from urllib.parse import quote
from dotenv import load_dotenv

# %%
pd.set_option('display.max_rows', 100)

# %%
#getting database password
load_dotenv()
password = os.getenv('DB_PASSWORD')

# %%
DBengine = sqlalchemy.create_engine("mysql+pymysql://student:{}@localhost:3306/dublinbus".format(quote(password)))

# %%
line = '40E' #bus line
direction = 1 #values of 1 or 2
dfBase = pd.read_sql('call dublinbus.trip_leavetimes_join("{}", {});'.format(line, direction) #using stored procedure
                 , DBengine)

# %%
print(len(dfBase), "rows")
dfBase.head(3)
# Out:
# 0 rows
# Empty DataFrame
# Columns: [dayofservice, tripid, lineid, direction, progrnumber, stoppointid, tripPlannedArr, tripPlannedDep, tripActualArr, tripActualDep, stopPlannedArr, stopPlannedDep, stopActualArr, stopActualDep, vehicleid]
# Index: []

# %%
#redundant columns
df = dfBase.drop(columns = ['vehicleid','tripPlannedArr','tripPlannedDep','tripActualArr','stopPlannedDep', 'stopPlannedArr'])
df.head(3)
# Out:
#          dayofservice   tripid lineid  direction  progrnumber  stoppointid  \
# 0  01-JAN-18 00:00:00  5955785     84          1            2         3082
# 1  01-JAN-18 00:00:00  5955785     84          1            4         3114
# 2  01-JAN-18 00:00:00  5955785     84          1            5         3115
#
#    tripActualDep  stopActualArr  stopActualDep
# 0        36583.0          36617          36629
# 1        36583.0          36782          36790
# 2        36583.0          36819          36819

# %%
#
df.rename(columns={'dayofservice': 'date'}, inplace=True)
df.date = pd.to_datetime(df.date, format="%d-%b-%y %H:%M:%S")
print(len(df),  "rows")
df.head(3)
# Out:
# 394884 rows
#         date   tripid lineid  direction  progrnumber  stoppointid  \
# 0 2018-01-01  5955785     84          1            2         3082
# 1 2018-01-01  5955785     84          1            4         3114
# 2 2018-01-01  5955785     84          1            5         3115
#
#    tripActualDep  stopActualArr  stopActualDep
# 0        36583.0          36617          36629
# 1        36583.0          36782          36790
# 2        36583.0          36819          36819

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# tripid                    int64
# lineid                   object
# direction                 int64
# progrnumber               int64
# stoppointid               int64
# tripActualDep           float64
# stopActualArr             int64
# stopActualDep             int64
# dtype: object

# %%
df.tripActualDep = df.tripActualDep.astype('Int64')

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# tripid                    int64
# lineid                   object
# direction                 int64
# progrnumber               int64
# stoppointid               int64
# tripActualDep             Int64
# stopActualArr             int64
# stopActualDep             int64
# dtype: object

# %%
df.sort_values(by = ['date', 'tripActualDep', 'progrnumber'], inplace=True)

# %%
df = df.reset_index(drop=True).dropna(subset='tripActualDep')

# %%
df.head(3)
# Out:
#         date   tripid lineid  direction  progrnumber  stoppointid  \
# 0 2018-01-01  5955785     84          1            1         7188
# 1 2018-01-01  5955785     84          1            2         3082
# 2 2018-01-01  5955785     84          1            3         7660
#
#    tripActualDep  stopActualArr  stopActualDep
# 0          36583          36583          36583
# 1          36583          36617          36629
# 2          36583          36721          36721

# %%
#getting the usual starting stop, will srop rows that have other stops
modeStartStop = df[df.progrnumber == 1].mode().stoppointid[0].astype('int64')

# %%
#df of unusual starting stops
dftmp = df[(df.progrnumber == 1) & (df.stoppointid != modeStartStop)]

#removing any entries from a trip with an unusual starting stop
df = df[(~df['date'].isin(dftmp['date'])) | (~df['tripid'].isin(dftmp['tripid']))].reset_index(drop=True) #should result in 375798-9442 rows
print(len(df),  "rows")
dftmp

# usually the different starting stop is a stop further up the line, something could be done with this data
# but whether it's a good use of time is debatable.
# Out:
# 366356 rows
#              date   tripid lineid  direction  progrnumber  stoppointid  \
# 1636   2018-01-02  5965755     84          1            1         4168
# 3239   2018-01-03  5965755     84          1            1         4168
# 4918   2018-01-04  5965755     84          1            1         4168
# 6428   2018-01-05  5965755     84          1            1         4168
# 9746   2018-01-08  6103348     84          1            1         4168
# ...           ...      ...    ...        ...          ...          ...
# 378366 2018-10-11  8030352     84          1            1         4168
# 380538 2018-10-16  8030352     84          1            1         4168
# 381991 2018-10-17  8030352     84          1            1         4168
# 383223 2018-10-18  8030352     84          1            1         4168
# 384667 2018-10-19  8030352     84          1            1         4168
#
#         tripActualDep  stopActualArr  stopActualDep
# 1636            56408          56408          56408
# 3239            56394          56394          56394
# 4918            56522          56522          56522
# 6428            56371          56371          56371
# 9746            56414          56414          56414
# ...               ...            ...            ...
# 378366          56334          56334          56334
# 380538          56427          56427          56427
# 381991          56353          56353          56353
# 383223          56432          56432          56432
# 384667          56619          56619          56619
#
# [219 rows x 9 columns]

# %%
#dealing with unusual, usually premature, last stop
#getting the index of the last stop for each trip
dftmp = df.groupby(['date','tripid']).progrnumber.idxmax().reset_index()

dftmp = df.iloc[dftmp.progrnumber] #all rows corresponding to a last stop
dftmp

# lastStopCounts = dftmp.stoppointid.value_counts()
# modeLastStop = dftmp.stoppointid.mode()[0]
# print(modeLastStop, lastStopCounts[modeLastStop])
# print('other', sum(lastStopCounts)-lastStopCounts[modeLastStop])
# max(lastStopCounts)/sum(lastStopCounts) #the mode last stop dominates so removing any other would be good
# Out:
#              date   tripid lineid  direction  progrnumber  stoppointid  \
# 85     2018-01-01  5955785     84          1           86         4956
# 255    2018-01-01  5955787     84          1           89         4956
# 427    2018-01-01  5955789     84          1           86         4956
# 600    2018-01-01  5955791     84          1           86         4956
# 771    2018-01-01  5955793     84          1           86         4956
# ...           ...      ...    ...        ...          ...          ...
# 365522 2018-10-27  8059369     84          1           87         4956
# 365727 2018-10-27  8059371     84          1           90         4956
# 365867 2018-10-27  8059373     84          1           86         7272
# 366064 2018-10-27  8059375     84          1           87         4956
# 366269 2018-10-27  8059377     84          1           87         4956
#
#         tripActualDep  stopActualArr  stopActualDep
# 85              36583          41351          41351
# 255             46212          51000          51000
# 427             55864          60201          60201
# 600             65420          70188          70188
# 771             74927          79206          79206
# ...               ...            ...            ...
# 365522          24010          28872          28872
# 365727          38515          43511          43511
# 365867          50365          56025          56025
# 366064          63235          68567          68567
# 366269          75618          80754          80754
#
# [4350 rows x 9 columns]

# %%
dftmp = dftmp[dftmp.stoppointid != modeLastStop].reset_index(drop=True)
dftmp = df.merge(dftmp, how='left', on=['date','tripid'], suffixes=(None,'Y'), indicator=True)
dftmp = dftmp[dftmp['_merge'] == "left_only"].drop(columns=['_merge'])
df = dftmp[list(df.columns)]

# %%
df
# Out:
#              date   tripid lineid  direction  progrnumber  stoppointid  \
# 0      2018-01-01  5955785     84          1            1         7188
# 1      2018-01-01  5955785     84          1            2         3082
# 2      2018-01-01  5955785     84          1            3         7660
# 3      2018-01-01  5955785     84          1            4         3114
# 4      2018-01-01  5955785     84          1            5         3115
# ...           ...      ...    ...        ...          ...          ...
# 366351 2018-10-27  8048174     84          1           83         4257
# 366352 2018-10-27  8048174     84          1           84         4258
# 366353 2018-10-27  8048174     84          1           85         4259
# 366354 2018-10-27  8048174     84          1           86         7272
# 366355 2018-10-27  8048174     84          1           87         4956
#
#         tripActualDep  stopActualArr  stopActualDep
# 0               36583          36583          36583
# 1               36583          36617          36629
# 2               36583          36721          36721
# 3               36583          36782          36790
# 4               36583          36819          36819
# ...               ...            ...            ...
# 366351          79168          83849          83849
# 366352          79168          83897          83897
# 366353          79168          83944          83944
# 366354          79168          83955          83955
# 366355          79168          84022          84022
#
# [347929 rows x 9 columns]

# %%
df[(df.date == '2018-01-08')&(df.tripid==6096287)]
# Out:
#            date   tripid lineid  direction  progrnumber  stoppointid  \
# 9762 2018-01-08  6096287     84          1            1         7188
# 9763 2018-01-08  6096287     84          1            2         3082
# 9764 2018-01-08  6096287     84          1            3         7660
# 9765 2018-01-08  6096287     84          1            4         3114
# 9766 2018-01-08  6096287     84          1            5         3115
# 9767 2018-01-08  6096287     84          1            6         3116
# 9768 2018-01-08  6096287     84          1            7         3117
# 9769 2018-01-08  6096287     84          1            8         3118
# 9770 2018-01-08  6096287     84          1            9         3119
# 9771 2018-01-08  6096287     84          1           10         3120
# 9772 2018-01-08  6096287     84          1           11         3122
# 9773 2018-01-08  6096287     84          1           12         3123
# 9774 2018-01-08  6096287     84          1           13         3124
# 9775 2018-01-08  6096287     84          1           14         3125
# 9776 2018-01-08  6096287     84          1           15         3126
# 9777 2018-01-08  6096287     84          1           16         3127
# 9778 2018-01-08  6096287     84          1           17         3128
# 9779 2018-01-08  6096287     84          1           18         7638
# 9780 2018-01-08  6096287     84          1           19         3130
# 9781 2018-01-08  6096287     84          1           20         3131
# 9782 2018-01-08  6096287     84          1           21         3132
# 9783 2018-01-08  6096287     84          1           22         3133
# 9784 2018-01-08  6096287     84          1           23         5046
# 9785 2018-01-08  6096287     84          1           24         7639
# 9786 2018-01-08  6096287     84          1           25         3134
# 9787 2018-01-08  6096287     84          1           26         3135
# 9788 2018-01-08  6096287     84          1           27         3136
# 9789 2018-01-08  6096287     84          1           28         3138
# 9790 2018-01-08  6096287     84          1           29         3139
# 9791 2018-01-08  6096287     84          1           30         4124
# 9792 2018-01-08  6096287     84          1           31         4125
# 9793 2018-01-08  6096287     84          1           32         4126
# 9794 2018-01-08  6096287     84          1           33         4127
# 9795 2018-01-08  6096287     84          1           34         4128
# 9796 2018-01-08  6096287     84          1           35         4129
# 9797 2018-01-08  6096287     84          1           36         4130
# 9798 2018-01-08  6096287     84          1           37         4131
# 9799 2018-01-08  6096287     84          1           38         7294
# 9800 2018-01-08  6096287     84          1           39         4156
# 9801 2018-01-08  6096287     84          1           40         4168
# 9802 2018-01-08  6096287     84          1           41         4170
# 9803 2018-01-08  6096287     84          1           42         4132
# 9804 2018-01-08  6096287     84          1           43         4134
# 9805 2018-01-08  6096287     84          1           44         4135
# 9806 2018-01-08  6096287     84          1           45         4136
# 9807 2018-01-08  6096287     84          1           46         4207
# 9808 2018-01-08  6096287     84          1           47         4208
# 9809 2018-01-08  6096287     84          1           48         4209
# 9810 2018-01-08  6096287     84          1           49         4210
# 9811 2018-01-08  6096287     84          1           50         4211
# 9812 2018-01-08  6096287     84          1           51         4212
# 9813 2018-01-08  6096287     84          1           52         4213
# 9814 2018-01-08  6096287     84          1           53         5139
# 9815 2018-01-08  6096287     84          1           54         4214
# 9816 2018-01-08  6096287     84          1           55         4215
# 9817 2018-01-08  6096287     84          1           56         4216
# 9818 2018-01-08  6096287     84          1           57         4217
# 9819 2018-01-08  6096287     84          1           58         4218
# 9820 2018-01-08  6096287     84          1           59         4219
# 9821 2018-01-08  6096287     84          1           60         4220
# 9822 2018-01-08  6096287     84          1           61         4221
# 9823 2018-01-08  6096287     84          1           62         4222
# 9824 2018-01-08  6096287     84          1           63         4224
# 9825 2018-01-08  6096287     84          1           64         4225
# 9826 2018-01-08  6096287     84          1           65         4226
# 9827 2018-01-08  6096287     84          1           66         4227
# 9828 2018-01-08  6096287     84          1           67         4228
# 9829 2018-01-08  6096287     84          1           68         4229
# 9830 2018-01-08  6096287     84          1           69         4230
# 9831 2018-01-08  6096287     84          1           70         4231
# 9832 2018-01-08  6096287     84          1           71         7352
# 9833 2018-01-08  6096287     84          1           72         4246
# 9834 2018-01-08  6096287     84          1           73         4248
# 9835 2018-01-08  6096287     84          1           74         4249
# 9836 2018-01-08  6096287     84          1           75         4250
# 9837 2018-01-08  6096287     84          1           76         4251
# 9838 2018-01-08  6096287     84          1           77         4252
# 9839 2018-01-08  6096287     84          1           78         4253
# 9840 2018-01-08  6096287     84          1           79         4254
# 9841 2018-01-08  6096287     84          1           80         6137
# 9842 2018-01-08  6096287     84          1           81         4256
# 9843 2018-01-08  6096287     84          1           82         4257
# 9844 2018-01-08  6096287     84          1           83         4258
# 9845 2018-01-08  6096287     84          1           84         4259
# 9846 2018-01-08  6096287     84          1           85         7272
# 9847 2018-01-08  6096287     84          1           86         4956
#
#       tripActualDep  stopActualArr  stopActualDep
# 9762          84441          84441          84441
# 9763          84441          84506          84600
# 9764          84441          84636          84636
# 9765          84441          84683          84696
# 9766          84441          84725          84725
# 9767          84441          84764          84764
# 9768          84441          84807          84817
# 9769          84441          84835          84835
# 9770          84441          84861          84861
# 9771          84441          84929          84936
# 9772          84441          84970          84970
# 9773          84441          84988          84988
# 9774          84441          85007          85007
# 9775          84441          85025          85025
# 9776          84441          85069          85069
# 9777          84441          85127          85127
# 9778          84441          85145          85157
# 9779          84441          85224          85224
# 9780          84441          85245          85245
# 9781          84441          85263          85263
# 9782          84441          85282          85282
# 9783          84441          85298          85298
# 9784          84441          85394          85407
# 9785          84441          85497          85497
# 9786          84441          85628          85636
# 9787          84441          85677          85677
# 9788          84441          85726          85726
# 9789          84441          85756          85756
# 9790          84441          85807          85807
# 9791          84441          85831          85831
# 9792          84441          85870          85870
# 9793          84441          85880          85880
# 9794          84441          85909          85909
# 9795          84441          85929          85929
# 9796          84441          85977          85977
# 9797          84441          86021          86021
# 9798          84441          86033          86033
# 9799          84441          86060          86060
# 9800          84441          86122          86122
# 9801          84441          86149          86420
# 9802          84441          86484          86484
# 9803          84441          86533          86566
# 9804          84441          86648          86648
# 9805          84441          86675          86675
# 9806          84441          86699          86712
# 9807          84441          86751          86751
# 9808          84441          86788          86788
# 9809          84441          86866          86866
# 9810          84441          86884          86884
# 9811          84441          86901          86901
# 9812          84441          86941          86941
# 9813          84441          86960          86960
# 9814          84441          86974          86974
# 9815          84441          87014          87014
# 9816          84441          87043          87052
# 9817          84441          87079          87079
# 9818          84441          87116          87126
# 9819          84441          87156          87156
# 9820          84441          87194          87194
# 9821          84441          87219          87219
# 9822          84441          87246          87246
# 9823          84441          87283          87283
# 9824          84441          87307          87319
# 9825          84441          87369          87369
# 9826          84441          87393          87405
# 9827          84441          87445          87445
# 9828          84441          87481          87481
# 9829          84441          87505          87512
# 9830          84441          87528          87528
# 9831          84441          87571          87571
# 9832          84441          87598          87598
# 9833          84441          87622          87622
# 9834          84441          87656          87673
# 9835          84441          87699          87699
# 9836          84441          87721          87721
# 9837          84441          87747          87756
# 9838          84441          87790          87790
# 9839          84441          87821          87821
# 9840          84441          87861          87876
# 9841          84441          87931          87931
# 9842          84441          87969          87969
# 9843          84441          87996          87996
# 9844          84441          88042          88042
# 9845          84441          88088          88088
# 9846          84441          88098          88098
# 9847          84441          88182          88182

# %%
df['journeytime'] = df.stopActualArr - df.tripActualDep
df['dwelltime'] = df.stopActualDep - df.stopActualArr
df.head(10)
# Out:
# /tmp/ipykernel_138083/2648235881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['journeytime'] = df.stopActualArr - df.tripActualDep
# /tmp/ipykernel_138083/2648235881.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dwelltime'] = df.stopActualDep - df.stopActualArr
#         date   tripid lineid  direction  progrnumber  stoppointid  \
# 0 2018-01-01  5955785     84          1            1         7188
# 1 2018-01-01  5955785     84          1            2         3082
# 2 2018-01-01  5955785     84          1            3         7660
# 3 2018-01-01  5955785     84          1            4         3114
# 4 2018-01-01  5955785     84          1            5         3115
# 5 2018-01-01  5955785     84          1            6         3116
# 6 2018-01-01  5955785     84          1            7         3117
# 7 2018-01-01  5955785     84          1            8         3118
# 8 2018-01-01  5955785     84          1            9         3119
# 9 2018-01-01  5955785     84          1           10         3120
#
#    tripActualDep  stopActualArr  stopActualDep  journeytime  dwelltime
# 0          36583          36583          36583            0          0
# 1          36583          36617          36629           34         12
# 2          36583          36721          36721          138          0
# 3          36583          36782          36790          199          8
# 4          36583          36819          36819          236          0
# 5          36583          36867          36867          284          0
# 6          36583          36905          36905          322          0
# 7          36583          36915          36915          332          0
# 8          36583          36936          36936          353          0
# 9          36583          36996          36996          413          0

# %%
df[(df.tripid == 6111779) & (df.progrnumber <3)]
# Out:
#             date   tripid lineid  direction  progrnumber  stoppointid  \
# 17983 2018-01-15  6111779     84          1            1         7188
# 17984 2018-01-15  6111779     84          1            2         3082
# 19464 2018-01-16  6111779     84          1            1         7188
# 19465 2018-01-16  6111779     84          1            2         3082
# 21004 2018-01-17  6111779     84          1            1         7188
# 21005 2018-01-17  6111779     84          1            2         3082
# 22463 2018-01-18  6111779     84          1            1         7188
# 22464 2018-01-18  6111779     84          1            2         3082
# 24015 2018-01-19  6111779     84          1            1         7188
# 24016 2018-01-19  6111779     84          1            2         3082
#
#        tripActualDep  stopActualArr  stopActualDep  journeytime  dwelltime
# 17983          31419          31419          31419            0          0
# 17984          31419          31488          31513           69         25
# 19464          32477          32477          32477            0          0
# 19465          32477          30780          30780        -1697          0
# 21004          32071          32071          32071            0          0
# 21005          32071          32163          32395           92        232
# 22463          32020          32020          32020            0          0
# 22464          32020          32211          32211          191          0
# 24015          31237          31237          31237            0          0
# 24016          31237          31281          31326           44         45

# %%
df.drop(columns=['tripActualDep','stopActualDep', 'lineid','direction','stoppointid'], inplace=True)
df.head(10)
# Out:
# /tmp/ipykernel_138083/3552021604.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['tripActualDep','stopActualDep', 'lineid','direction','stoppointid'], inplace=True)
#         date   tripid  progrnumber  stopActualArr  journeytime  dwelltime
# 0 2018-01-01  5955785            1          36583            0          0
# 1 2018-01-01  5955785            2          36617           34         12
# 2 2018-01-01  5955785            3          36721          138          0
# 3 2018-01-01  5955785            4          36782          199          8
# 4 2018-01-01  5955785            5          36819          236          0
# 5 2018-01-01  5955785            6          36867          284          0
# 6 2018-01-01  5955785            7          36905          322          0
# 7 2018-01-01  5955785            8          36915          332          0
# 8 2018-01-01  5955785            9          36936          353          0
# 9 2018-01-01  5955785           10          36996          413          0

# %%
max(df.stopActualArr)
# Out:
# 90289

# %%
#getting weather dataframe
dfWeather = pd.read_sql('select * from weather;', DBengine)
dfWeather
# Out:
#                   date  rain  temp  humidity  pressure
# 0     01/01/2018 00:00   0.0   4.6        82     991.0
# 1     01/01/2018 01:00   0.1   4.7        81     991.1
# 2     01/01/2018 02:00   0.0   4.8        81     991.1
# 3     01/01/2018 03:00   0.0   4.9        82     990.7
# 4     01/01/2018 04:00   0.0   5.3        81     990.3
# ...                ...   ...   ...       ...       ...
# 8756  31/12/2018 19:00   0.0   9.9        74    1034.9
# 8757  31/12/2018 20:00   0.0   9.9        75    1035.0
# 8758  31/12/2018 21:00   0.0   9.9        75    1035.0
# 8759  31/12/2018 22:00   0.0   9.9        76    1035.1
# 8760  31/12/2018 23:00   0.0   9.8        75    1035.2
#
# [8761 rows x 5 columns]

# %%
dfWeather.dtypes
# Out:
# date         object
# rain        float64
# temp        float64
# humidity      int64
# pressure    float64
# dtype: object

# %%
dfWeather['date'] = pd.to_datetime(dfWeather.date, format="%d/%m/%Y %H:%M")
dfWeather.head(3)
# Out:
#                  date  rain  temp  humidity  pressure
# 0 2018-01-01 00:00:00   0.0   4.6        82     991.0
# 1 2018-01-01 01:00:00   0.1   4.7        81     991.1
# 2 2018-01-01 02:00:00   0.0   4.8        81     991.1

# %%
#new columns to make merging into bus data easier
dfWeather['hour'] = dfWeather.date.dt.hour
dfWeather['date'] = dfWeather.date.dt.date
dfWeather['date'] = pd.to_datetime(dfWeather.date, format = "%Y-%m-%d")

# %%
dfWeather.head(3)
# Out:
#         date  rain  temp  humidity  pressure  hour
# 0 2018-01-01   0.0   4.6        82     991.0     0
# 1 2018-01-01   0.1   4.7        81     991.1     1
# 2 2018-01-01   0.0   4.8        81     991.1     2

# %%
dfWeather.dtypes
# Out:
# date        datetime64[ns]
# rain               float64
# temp               float64
# humidity             int64
# pressure           float64
# hour                 int64
# dtype: object

# %%
#temporary columns to join to weather to deal with some stops happening in hours 24 and 25 of a day
#I think this happens as they don't want the date to rollover in the middle of a bus trip
df['hour'] = df.stopActualArr//3600
df['day'] = df['date']

#in new column rollover the date when hour is >23, also subtract 24 from hour
#now all rows should be able to match to a weather row
df.loc[df.hour > 23, ['day']] += pd.Timedelta(days=1)
df.loc[df.hour > 23, ['hour']] -=24
# Out:
# /tmp/ipykernel_138083/3026850418.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.stopActualArr//3600
# /tmp/ipykernel_138083/3026850418.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['date']

# %%
df = df.merge(dfWeather, how='left', left_on = ['day','hour'], right_on = ['date','hour'])

# %%
df.rename(columns={'date_x':'date'},inplace=True)
df.drop(columns=['hour','day','date_y'], inplace=True)

# %%
#checking if any nulls exist
df.isna().sum()
# Out:
# date             0
# tripid           0
# progrnumber      0
# stopActualArr    0
# journeytime      0
# dwelltime        0
# rain             0
# temp             0
# humidity         0
# pressure         0
# dtype: int64

# %%
df.head(3)
# Out:
#         date   tripid  progrnumber  stopActualArr  journeytime  dwelltime  \
# 0 2018-01-01  5955785            1          36583            0          0
# 1 2018-01-01  5955785            2          36617           34         12
# 2 2018-01-01  5955785            3          36721          138          0
#
#    rain  temp  humidity  pressure
# 0   0.0   5.6        79     992.9
# 1   0.0   5.6        79     992.9
# 2   0.0   5.6        79     992.9

# %%
#removing trips that have a negative trip time along any point
dftmp = df[(df.journeytime <= 0) & (df.progrnumber > 1)]
df = df[~df['date'].isin(dftmp['date']) | ~df['tripid'].isin(dftmp['tripid'])].reset_index()
df
# Out:
#          index       date   tripid  progrnumber  stopActualArr  journeytime  \
# 0            0 2018-01-01  5955785            1          36583            0
# 1            1 2018-01-01  5955785            2          36617           34
# 2            2 2018-01-01  5955785            3          36721          138
# 3            3 2018-01-01  5955785            4          36782          199
# 4            4 2018-01-01  5955785            5          36819          236
# ...        ...        ...      ...          ...            ...          ...
# 345481  347924 2018-10-27  8048174           83          83849         4681
# 345482  347925 2018-10-27  8048174           84          83897         4729
# 345483  347926 2018-10-27  8048174           85          83944         4776
# 345484  347927 2018-10-27  8048174           86          83955         4787
# 345485  347928 2018-10-27  8048174           87          84022         4854
#
#         dwelltime  rain  temp  humidity  pressure
# 0               0   0.0   5.6        79     992.9
# 1              12   0.0   5.6        79     992.9
# 2               0   0.0   5.6        79     992.9
# 3               8   0.0   5.6        79     992.9
# 4               0   0.0   5.6        79     992.9
# ...           ...   ...   ...       ...       ...
# 345481          0   0.0   2.6        78    1026.1
# 345482          0   0.0   2.6        78    1026.1
# 345483          0   0.0   2.6        78    1026.1
# 345484          0   0.0   2.6        78    1026.1
# 345485          0   0.0   2.6        78    1026.1
#
# [345486 rows x 11 columns]
